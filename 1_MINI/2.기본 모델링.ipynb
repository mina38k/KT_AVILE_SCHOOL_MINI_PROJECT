# %% [markdown]
# #**스마트폰 센서 데이터 기반 모션 분류**
# # 단계2 : 기본 모델링

# %% [markdown]
# ## 0.미션3

# %% [markdown]
# * 데이터 전처리
#     * 가변수화, 데이터 분할, NaN 확인 및 조치, 스케일링 등 필요한 전처리 수행
# * 다양한 딥러닝 구조의 모델로 분류 모델 생성
#     * 최소 4개 이상 모델링 수행
#     * 각 모델별 최소 5회 반복수행해서 얻은 성능의 평균으로 비교
#     * 각 모델의 성능을 저장하는 별도 데이터 프레임을 만들고 비교
# * 옵션 : 다음 사항은 선택사항입니다. 시간이 허용하는 범위 내에서 수행하세요.
#     * 상위 N개 변수를 선정하여 모델링 및 성능 비교
#         * 모델링에 항상 모든 변수가 필요한 것은 아닙니다.
#         * 변수 중요도 상위 N개를 선정하여 모델링하고 타 모델과 성능을 비교하세요.
#         * 상위 N개를 선택하는 방법은, 변수를 하나씩 늘려가며 모델링 및 성능 검증을 수행하여 적절한 지점을 찾는 것입니다.
# * 성능 가이드
#     * Accuracy : 0.90 ~ 0.99

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# * 세부 요구사항
#     - 경로 설정 : 구글콜랩
#         * 구글 드라이브 바로 밑에 project3 폴더를 만들고,
#         * 데이터 파일을 복사해 넣습니다.
#     - 기본적으로 필요한 라이브러리를 import 하도록 코드가 작성되어 있습니다.
#         * 필요하다고 판단되는 라이브러리를 추가하세요.

# %% [markdown]
# ### (1) 경로 설정

# %% [markdown]
# * 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/project3/'

# %%
# !pip install koreanize_matplotlib
import koreanize_matplotlib
# Out:
# Collecting koreanize_matplotlib
#   Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl.metadata (992 bytes)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from koreanize_matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize_matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize_matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize_matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize_matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize_matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize_matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize_matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize_matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize_matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize_matplotlib) (1.17.0)
# Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 36.8 MB/s eta 0:00:00
# Installing collected packages: koreanize_matplotlib
# Successfully installed koreanize_matplotlib-0.1.1

# %% [markdown]
# ### (2) 라이브러리 불러오기

# %% [markdown]
# * 라이브러리 로딩
#      - pandas, numpy,matplotlib,seaborn, joblib, 모델링에 필요한 라이브러리를 로딩합니다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import joblib
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import *

from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Input, BatchNormalization
from keras.backend import clear_session
from keras.optimizers import Adam

# %%
# 학습곡선 함수
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### (3) 데이터 불러오기

# %% [markdown]
# * 주어진 데이터셋
#     * data01_train.csv : 학습 및 검증용
#     * data01_test.csv : 테스트용
#     * feature.csv : feature 이름을 계층구조로 정리한 데이터
#
# * 세부 요구사항
#     * 칼럼 삭제 : data01_train.csv와 data01_test.csv 에서 'subject' 칼럼은 불필요하므로 삭제합니다.

# %% [markdown]
# #### 1) 데이터로딩

# %%
# 주어진 데이터 셋을 불러오세요.(3개)
train_data = pd.read_csv(path + 'data01_train.csv')
test_data = pd.read_csv(path + 'data01_test.csv')
features = pd.read_csv(path + 'features.csv')

# %%
#불필요한 칼럼을 삭제하세요.
train_data.drop('subject', axis=1, inplace=True)
test_data.drop('subject', axis=1, inplace=True)

# %% [markdown]
# #### 2) 기본 정보 조회

# %%
#전체 데이터의 행,열 개수 확인
print("train 데이터 크기 (행, 열):", train_data.shape)
print("test 데이터 크기 (행, 열):", test_data.shape)
print("features 데이터 크기 (행, 열):", features.shape)
# Out:
# train 데이터 크기 (행, 열): (5881, 562)
# test 데이터 크기 (행, 열): (1471, 562)
# features 데이터 크기 (행, 열): (561, 4)

# %%
#전체 데이터의 상위 5개 행 확인
print("train 데이터 :")
display(train_data.head(5))

print("\ntest 데이터 :")
display(test_data.head(5))

print("\nfeatures 데이터 :")
display(features.head(5))
# Out:
# train 데이터 :
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288508          -0.009196          -0.103362         -0.988986
# 1           0.265757          -0.016576          -0.098163         -0.989551
# 2           0.278709          -0.014511          -0.108717         -0.997720
# 3           0.289795          -0.035536          -0.150354         -0.231727
# 4           0.394807           0.034098           0.091229          0.088489
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.962797         -0.967422         -0.989000         -0.962596
# 1         -0.994636         -0.987435         -0.990189         -0.993870
# 2         -0.981088         -0.994008         -0.997934         -0.982187
# 3         -0.006412         -0.338117         -0.273557          0.014245
# 4         -0.106636         -0.388502         -0.010469         -0.109680
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-skewness()  \
# 0         -0.965650         -0.929747  ...                        -0.487737
# 1         -0.987558         -0.937337  ...                        -0.237820
# 2         -0.995017         -0.942584  ...                        -0.535287
# 3         -0.347916          0.008288  ...                        -0.004012
# 4         -0.346372          0.584131  ...                        -0.157832
#
#    fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 0                        -0.816696                    -0.042494
# 1                        -0.693515                    -0.062899
# 2                        -0.829311                     0.000265
# 3                        -0.408956                    -0.255125
# 4                        -0.563437                    -0.044344
#
#    angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                             -0.044218                          0.307873
# 1                              0.388459                         -0.765014
# 2                             -0.525022                         -0.891875
# 3                              0.612804                          0.747381
# 4                             -0.845268                         -0.974650
#
#    angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                              0.072790             -0.601120
# 1                              0.771524              0.345205
# 2                              0.021528             -0.833564
# 3                             -0.072944             -0.695819
# 4                             -0.887846             -0.705029
#
#    angle(Y,gravityMean)  angle(Z,gravityMean)            Activity
# 0              0.331298              0.165163            STANDING
# 1             -0.769186             -0.147944              LAYING
# 2              0.202434             -0.032755            STANDING
# 3              0.287154              0.111388             WALKING
# 4              0.264952              0.137758  WALKING_DOWNSTAIRS
#
# [5 rows x 562 columns]
# test 데이터 :
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.284379          -0.021981          -0.116683         -0.992490
# 1           0.277440          -0.028086          -0.118412         -0.996620
# 2           0.305833          -0.041023          -0.087303          0.006880
# 3           0.276053          -0.016487          -0.108381         -0.995379
# 4           0.271998           0.016904          -0.078856         -0.973468
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.979640         -0.963321         -0.992563         -0.977304
# 1         -0.927676         -0.972294         -0.997346         -0.931405
# 2          0.182800         -0.237984          0.005642          0.028616
# 3         -0.983978         -0.975854         -0.995877         -0.985280
# 4         -0.702462         -0.869450         -0.979810         -0.711601
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-skewness()  \
# 0         -0.958142         -0.938850  ...                        -0.509523
# 1         -0.971788         -0.939837  ...                        -0.210792
# 2         -0.236474          0.016311  ...                         0.579587
# 3         -0.974907         -0.941425  ...                        -0.566291
# 4         -0.856807         -0.920760  ...                         0.447577
#
#    fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 0                        -0.850065                    -0.018043
# 1                        -0.613367                    -0.022456
# 2                         0.394388                    -0.362616
# 3                        -0.841455                     0.289548
# 4                         0.214219                     0.010111
#
#    angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                              0.092304                          0.074220
# 1                             -0.155414                          0.247498
# 2                              0.171069                          0.576349
# 3                              0.079801                         -0.020033
# 4                              0.114179                         -0.830776
#
#    angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                             -0.714534             -0.671943
# 1                             -0.112257             -0.826816
# 2                             -0.688314             -0.743234
# 3                              0.291898             -0.639435
# 4                             -0.325098             -0.840817
#
#    angle(Y,gravityMean)  angle(Z,gravityMean)  Activity
# 0             -0.018351             -0.185733   SITTING
# 1              0.184489             -0.068699  STANDING
# 2              0.272186              0.053101   WALKING
# 3             -0.111998             -0.123298   SITTING
# 4              0.116237             -0.096615  STANDING
#
# [5 rows x 562 columns]
# features 데이터 :
#      sensor     agg axis       feature_name
# 0  tBodyAcc  mean()    X  tBodyAcc-mean()-X
# 1  tBodyAcc  mean()    Y  tBodyAcc-mean()-Y
# 2  tBodyAcc  mean()    Z  tBodyAcc-mean()-Z
# 3  tBodyAcc   std()    X   tBodyAcc-std()-X
# 4  tBodyAcc   std()    Y   tBodyAcc-std()-Y

# %%
#전체 데이터의 수치형 변수 분포 확인
print("train 데이터 (수치형):")
display(train_data.describe())

print("\ntest 데이터 (수치형):")
display(test_data.describe())

print("\nfeatures 데이터 (수치형):")
display(features.describe())
# Out:
# train 데이터 (수치형):
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       1471.000000       1471.000000       1471.000000       1471.000000
# mean          -0.614634         -0.515427         -0.607533         -0.639950
# std            0.448480          0.506094          0.424243          0.422994
# min           -0.999717         -0.999873         -1.000000         -0.999867
# 25%           -0.992669         -0.979082         -0.981070         -0.993498
# 50%           -0.952426         -0.867309         -0.869890         -0.958705
# 75%           -0.245405         -0.030639         -0.260223         -0.297260
# max            0.899922          0.782590          0.931308          0.950758
#
#        tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# count       1471.000000       1471.000000       1471.000000  ...
# mean          -0.530760         -0.609256         -0.481055  ...
# std            0.489381          0.418536          0.542756  ...
# min           -1.000000         -0.999879         -0.948723  ...
# 25%           -0.979214         -0.980659         -0.936791  ...
# 50%           -0.873891         -0.863451         -0.890491  ...
# 75%           -0.058824         -0.256657         -0.030692  ...
# max            0.602458          0.784041          0.821218  ...
#
#        fBodyBodyGyroJerkMag-meanFreq()  fBodyBodyGyroJerkMag-skewness()  \
# count                      1471.000000                      1471.000000
# mean                          0.118651                        -0.311513
# std                           0.258112                         0.313792
# min                          -1.000000                        -0.995357
# 25%                          -0.035193                        -0.546342
# 50%                           0.135282                        -0.347433
# 75%                           0.289832                        -0.125796
# max                           0.860512                         0.941113
#
#        fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# count                      1471.000000                  1471.000000
# mean                         -0.632273                     0.009324
# std                           0.296179                     0.324864
# min                          -0.994664                    -0.937468
# 25%                          -0.844547                    -0.119166
# 50%                          -0.706699                     0.005049
# 75%                          -0.516910                     0.135698
# max                           0.894210                     0.980889
#
#        angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# count                           1471.000000                       1471.000000
# mean                               0.015666                          0.006272
# std                                0.452616                          0.608954
# min                               -0.990492                         -0.995222
# 25%                               -0.265533                         -0.485998
# 50%                                0.023421                         -0.005036
# 75%                                0.312690                          0.518184
# max                                0.991899                          0.994366
#
#        angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# count                           1471.000000           1471.000000
# mean                              -0.001510             -0.481737
# std                                0.483028              0.522714
# min                               -0.969066             -0.999380
# 25%                               -0.380300             -0.814060
# 50%                                0.002408             -0.708911
# 75%                                0.374583             -0.486534
# max                                0.979522              1.000000
#
#        angle(Y,gravityMean)  angle(Z,gravityMean)
# count           1471.000000           1471.000000
# mean               0.055771             -0.064194
# std                0.298124              0.281645
# min               -0.995073             -1.000000
# 25%               -0.017413             -0.148445
# 50%                0.178814             -0.002243
# 75%                0.248126              0.096674
# max                0.432496              0.992766
#
# [8 rows x 561 columns]
# features 데이터 (수치형):
#            sensor            agg axis          feature_name
# count         561            561  436                   561
# unique         18             27   62                   561
# top     fBodyGyro  bandsEnergy()    X  angle(Z,gravityMean)
# freq           79            126   76                     1

# %%
#전체 데이터의 모든 변수 확인
print(train_data.columns)
print('')
print(test_data.columns)
print('')
print(features.columns)
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-skewness()', 'fBodyBodyGyroJerkMag-kurtosis()',
#        'angle(tBodyAccMean,gravity)', 'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'Activity'],
#       dtype='object', length=562)
#
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-skewness()', 'fBodyBodyGyroJerkMag-kurtosis()',
#        'angle(tBodyAccMean,gravity)', 'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'Activity'],
#       dtype='object', length=562)
#
# Index(['sensor', 'agg', 'axis', 'feature_name'], dtype='object')

# %%
#(추가) 다양하게 기본 정보들을 확인하세요!
# train 데이터의 정보 확인
print("train_df 정보:")
train_data.info()

# test 데이터의 정보 확인
print("\ntest_df 정보:")
test_data.info()

# Feature 데이터 정보 확인
print("\nFeature 데이터 정보:")
features.info()
# Out:
# train_df 정보:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5881 entries, 0 to 5880
# Columns: 562 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), object(1)
# memory usage: 25.2+ MB
#
# test_df 정보:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1471 entries, 0 to 1470
# Columns: 562 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), object(1)
# memory usage: 6.3+ MB
#
# Feature 데이터 정보:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sensor        561 non-null    object
#  1   agg           561 non-null    object
#  2   axis          436 non-null    object
#  3   feature_name  561 non-null    object
# dtypes: object(4)
# memory usage: 17.7+ KB

# %% [markdown]
# ## **2. 데이터 전처리**
#
# * 가변수화, 데이터 분할, NaN 확인 및 조치, 스케일링 등 필요한 전처리를 수행한다.

# %% [markdown]
# ### (1) 데이터 분할1 : x, y

# %% [markdown]
# * 세부 요구사항
#     - x, y로 분할합니다.

# %%
# 데이터 분할을 합니다.
x = train_data.drop(columns=['Activity'])
y = train_data['Activity']

# %% [markdown]
# ### (2) 데이터분할2 : train, validation

# %% [markdown]
# * 세부 요구사항
#     - train : val = 8 : 2 혹은 7 : 3
#     - random_state 옵션을 사용하여 다른 모델과 비교를 위해 성능이 재현되도록 합니다.

# %%
#데이터 분할 진행(train:val = 8:2 혹은 7:3 권장)
x_train, x_val, y_train, y_val = train_test_split(
      x,
      y,
      test_size=0.2,
      random_state=42,
      stratify=y # 비율 유지
    )

# %% [markdown]
# ### (3) 스케일링

# %% [markdown]
# * 세부 요구사항
#     - 스케일링을 필요로 하는 알고리즘 사용을 위해서 코드 수행
#     - min-max 방식 혹은 standard 방식 중 한가지 사용.

# %%
#스케일링 방식을 선택해서 스케일링을 진행합니다.
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)
print(x_train.shape, x_val.shape)
# Out:
# (4704, 561) (1177, 561)

# %% [markdown]
# ### (4) Y 전처리
# * integer encoding : LabelEncoder
# * (필요시) one-hot encoding

# %%
# 정수 인코딩 변환(LabelEncoder)
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_val = le.transform(y_val)
print(y_train)
print(y_val)
# Out:
# [5 1 3 ... 4 1 0]
# [0 1 3 ... 5 2 3]

# %%
# 기존 레이블 저장

# 정수 인코딩된 레이블을 DataFrame으로 저장
encoded_df = pd.DataFrame(y_train, columns=['encoded_label'])

# %% [markdown]
# ## **3. 기본 모델링**

# %% [markdown]
# * 세부 요구사항
#     - 모델1 : Base line 모델
#         * Hidden Layer 없이 모델 생성
#     - 모델2 : 복잡한 모델 생성
#         * 최소 5개 이상의 은닉층을 추가한 모델
#     - 모델3 ~ n : 튜닝 모델
#         * 학습률, epoch 등 조정
#         * 모델2에 과적합을 방지하기 위한 규제 기법 추가
#         * Accuracy 최대화 시키는 모델 생성하기
#     - (옵션) 각 모델은 최소 5번 반복수행해서 얻은 성능의 평균값을 기록

# %% [markdown]
# ### (1) 모델1 : Hidden Layer 없이 모델 생성

# %%
# 모델 설계

# 입력 데이터의 특성 수 확인
input_dim = x_train.shape[1]
num_classes = len(np.unique(y_train))

# 모델1: Hidden Layer 없이 Output만 있는 구조
def build_model1():
    model = Sequential([
        Input(shape=(input_dim,)),
        Dense(num_classes, activation='softmax')  # 출력층만
    ])
    return model

model1 = build_model1()
model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 6)              │         3,372 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,372 (13.17 KB)
#  Trainable params: 3,372 (13.17 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#
# Epoch 36/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9811 - loss: 0.0592 - val_accuracy: 0.9762 - val_loss: 0.0774
# Epoch 37/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9819 - loss: 0.0560 - val_accuracy: 0.9728 - val_loss: 0.0818
# Epoch 38/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9867 - loss: 0.0531 - val_accuracy: 0.9796 - val_loss: 0.0713
# Epoch 39/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9865 - loss: 0.0536 - val_accuracy: 0.9813 - val_loss: 0.0711
# Epoch 40/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9837 - loss: 0.0541 - val_accuracy: 0.9796 - val_loss: 0.0702
# Epoch 41/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9845 - loss: 0.0533 - val_accuracy: 0.9779 - val_loss: 0.0710
# Epoch 42/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9822 - loss: 0.0549 - val_accuracy: 0.9856 - val_loss: 0.0671
# Epoch 43/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9835 - loss: 0.0516 - val_accuracy: 0.9847 - val_loss: 0.0665
# Epoch 44/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9835 - loss: 0.0523 - val_accuracy: 0.9830 - val_loss: 0.0673
# Epoch 45/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9842 - loss: 0.0530 - val_accuracy: 0.9762 - val_loss: 0.0732
# Epoch 46/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9831 - loss: 0.0501 - val_accuracy: 0.9839 - val_loss: 0.0645
# Epoch 47/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9862 - loss: 0.0452 - val_accuracy: 0.9813 - val_loss: 0.0667
# Epoch 48/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9888 - loss: 0.0447 - val_accuracy: 0.9805 - val_loss: 0.0664
# Epoch 49/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9842 - loss: 0.0493 - val_accuracy: 0.9830 - val_loss: 0.0634
# Epoch 50/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9855 - loss: 0.0497 - val_accuracy: 0.9856 - val_loss: 0.0615

# %%
# 학습곡선
dl_history_plot(history1.history)

# %%
# 예측 및 평가
val_loss, val_acc = model1.evaluate(x_val, y_val, verbose=0)
print(f"모델1 정확도(Validation): {val_acc:.4f}")
# Out:
# 모델1 정확도(Validation): 0.9856

# %%
#(옵션) 모델1번을 최소 5번 반복수행해서 얻은 성능의 평균값을 기록해보자!
acc_list = []

for i in range(5):
    clear_session()
    model = build_model1()
    model.compile(optimizer=Adam(learning_rate=0.005),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    model.fit(x_train, y_train, validation_data=(x_val, y_val),
              epochs=30, batch_size=64, verbose=0)
    _, acc = model.evaluate(x_val, y_val, verbose=0)
    acc_list.append(acc)
    print(f"{i+1}회 검증 정확도: {acc:.4f}")


avg_acc = np.mean(acc_list)
print(f"\n모델1 평균 정확도 (5회): {avg_acc:.4f}")
# Out:
# 0회 검증 정확도: 0.9745
# 1회 검증 정확도: 0.9754
# 2회 검증 정확도: 0.9779
# 3회 검증 정확도: 0.9745
# 4회 검증 정확도: 0.9796
#
# 모델1 평균 정확도 (5회): 0.9764

# %% [markdown]
# ### (2) 모델2 : 최소 5개 이상의 은닉층을 추가한 모델

# %%
# 모델 설계
def build_model2():
    model = Sequential([
        Input(shape=(input_dim,)),               # 입력층
        Dense(256, activation='relu'),           # 은닉층 1
        Dense(128, activation='relu'),            # 은닉층 2
        Dense(128, activation='relu'),            # 은닉층 3
        Dense(64, activation='relu'),            # 은닉층 4
        Dense(64, activation='relu'),            # 은닉층 5
        Dense(num_classes, activation='softmax') # 출력층
    ])
    return model

model2 = build_model2()
model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 256)            │       143,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 206,086 (805.02 KB)
#  Trainable params: 206,086 (805.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 컴파일 및 학습

# 컴파일
model2.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# 학습
history2 = model2.fit(
    x_train, y_train,
    validation_data=(x_val, y_val), # 검증 데이터
    epochs=30,
    batch_size=64,
    verbose=1
)
# Out:
# Epoch 1/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9870 - loss: 0.0357 - val_accuracy: 0.9881 - val_loss: 0.0433

# %%
# 학습곡선
dl_history_plot(history2.history)

# %%
# 예측 및 평가
val_loss2, val_acc2 = model2.evaluate(x_val, y_val, verbose=0)
print(f"모델2 정확도(Validation): {val_acc2:.4f}")
# Out:
# 모델2 정확도(Validation): 0.9881

# %% [markdown]
# ### (3) 모델3 : 학습률, epoch 등 조정

# %%
# 모델 설계
def build_model3():
    model = Sequential([
        Input(shape=(input_dim,)),               # 입력층
        Dense(256, activation='relu'),
        Dropout(0.3), # 과적합 방지
        Dense(128, activation='relu'),
        Dropout(0.3), # 과적합 방지
        Dense(128, activation='relu'),
        Dropout(0.2), # 과적합 방지
        Dense(64, activation='relu'),
        Dropout(0.2), # 과적합 방지
        Dense(64, activation='relu'),
        Dense(num_classes, activation='softmax') # 출력층
    ])
    return model

model3 = build_model3()
model3.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                 │ (None, 256)            │       143,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 206,086 (805.02 KB)
#  Trainable params: 206,086 (805.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 컴파일 및 학습
model3.compile(
    optimizer=Adam(learning_rate=0.0005),  # 학습률 조정
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history3 = model3.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=50,  # 에폭 증가
    batch_size=64,
    verbose=1
)
# Out:
# Epoch 1/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.2678 - loss: 1.6129 - val_accuracy: 0.6245 - val_loss: 0.9295
# Epoch 2/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5585 - loss: 0.9286 - val_accuracy: 0.7715 - val_loss: 0.5282
# Epoch 3/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7259 - loss: 0.5843 - val_accuracy: 0.8131 - val_loss: 0.3809
# Epoch 4/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8394 - loss: 0.3933 - val_accuracy: 0.9006 - val_loss: 0.2449
# Epoch 5/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8726 - loss: 0.3212 - val_accuracy: 0.9125 - val_loss: 0.2187
# Epoch 6/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8973 - loss: 0.2554 - val_accuracy: 0.9116 - val_loss: 0.2368
# Epoch 7/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9197 - loss: 0.2153 - val_accuracy: 0.9397 - val_loss: 0.1538
# Epoch 8/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9320 - loss: 0.1736 - val_accuracy: 0.9473 - val_loss: 0.1293
# Epoch 9/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9425 - loss: 0.1575 - val_accuracy: 0.9465 - val_loss: 0.1462
# Epoch 10/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9423 - loss: 0.1586 - val_accuracy: 0.9677 - val_loss: 0.1002
# Epoch 11/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9498 - loss: 0.1345 - val_accuracy: 0.9567 - val_loss: 0.1196
# Epoch 12/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9468 - loss: 0.1401 - val_accuracy: 0.9482 - val_loss: 0.1378
# Epoch 13/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9536 - loss: 0.1259 - val_accuracy: 0.9669 - val_loss: 0.0887
# Epoch 14/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9554 - loss: 0.1254 - val_accuracy: 0.9703 - val_loss: 0.0945
# Epoch 15/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9590 - loss: 0.1072 - val_accuracy: 0.9618 - val_loss: 0.1067
# Epoch 16/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9546 - loss: 0.1190 - val_accuracy: 0.9779 - val_loss: 0.0694
# Epoch 17/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9630 - loss: 0.1000 - val_accuracy: 0.9694 - val_loss: 0.0905
# Epoch 18/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9671 - loss: 0.0910 - val_accuracy: 0.9728 - val_loss: 0.0807
# Epoch 19/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9628 - loss: 0.1050 - val_accuracy: 0.9813 - val_loss: 0.0595
# Epoch 20/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9699 - loss: 0.0731 - val_accuracy: 0.9635 - val_loss: 0.1046
# Epoch 21/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9679 - loss: 0.0916 - val_accuracy: 0.9771 - val_loss: 0.0712
# Epoch 22/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9688 - loss: 0.0875 - val_accuracy: 0.9796 - val_loss: 0.0592
# Epoch 23/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9651 - loss: 0.0904 - val_accuracy: 0.9788 - val_loss: 0.0631
# Epoch 24/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9701 - loss: 0.0786 - val_accuracy: 0.9618 - val_loss: 0.1054
# Epoch 25/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9739 - loss: 0.0820 - val_accuracy: 0.9762 - val_loss: 0.0743
# Epoch 26/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9679 - loss: 0.0894 - val_accuracy: 0.9694 - val_loss: 0.0940
# Epoch 27/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9640 - loss: 0.1023 - val_accuracy: 0.9839 - val_loss: 0.0595
# Epoch 28/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9731 - loss: 0.0712 - val_accuracy: 0.9839 - val_loss: 0.0631
# Epoch 29/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9721 - loss: 0.0690 - val_accuracy: 0.9839 - val_loss: 0.0613
# Epoch 30/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9682 - loss: 0.0827 - val_accuracy: 0.9813 - val_loss: 0.0776
# Epoch 31/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9715 - loss: 0.0798 - val_accuracy: 0.9703 - val_loss: 0.0825
# Epoch 32/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9687 - loss: 0.0932 - val_accuracy: 0.9890 - val_loss: 0.0521
# Epoch 33/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9783 - loss: 0.0589 - val_accuracy: 0.9830 - val_loss: 0.0557
# Epoch 34/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9767 - loss: 0.0543 - val_accuracy: 0.9847 - val_loss: 0.0602
# Epoch 35/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9646 - loss: 0.1047 - val_accuracy: 0.9847 - val_loss: 0.0578
# Epoch 36/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9749 - loss: 0.0717 - val_accuracy: 0.9839 - val_loss: 0.0599
# Epoch 37/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9789 - loss: 0.0639 - val_accuracy: 0.9873 - val_loss: 0.0507
# Epoch 38/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9750 - loss: 0.0612 - val_accuracy: 0.9847 - val_loss: 0.0542
# Epoch 39/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9745 - loss: 0.0715 - val_accuracy: 0.9822 - val_loss: 0.0629
# Epoch 40/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9812 - loss: 0.0526 - val_accuracy: 0.9703 - val_loss: 0.1142
# Epoch 41/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9694 - loss: 0.0862 - val_accuracy: 0.9813 - val_loss: 0.0555
# Epoch 42/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9864 - loss: 0.0410 - val_accuracy: 0.9856 - val_loss: 0.0599
# Epoch 43/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9754 - loss: 0.0669 - val_accuracy: 0.9839 - val_loss: 0.0532
# Epoch 44/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9810 - loss: 0.0531 - val_accuracy: 0.9873 - val_loss: 0.0566
# Epoch 45/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9773 - loss: 0.0697 - val_accuracy: 0.9805 - val_loss: 0.0624
# Epoch 46/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9803 - loss: 0.0525 - val_accuracy: 0.9737 - val_loss: 0.0892
# Epoch 47/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9763 - loss: 0.0675 - val_accuracy: 0.9847 - val_loss: 0.0518
# Epoch 48/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9785 - loss: 0.0575 - val_accuracy: 0.9915 - val_loss: 0.0452
# Epoch 49/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9849 - loss: 0.0465 - val_accuracy: 0.9839 - val_loss: 0.0509
# Epoch 50/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9745 - loss: 0.0723 - val_accuracy: 0.9873 - val_loss: 0.0491

# %%
# 학습곡선
dl_history_plot(history3.history)

# %%
# 예측 및 평가
val_loss3, val_acc3 = model3.evaluate(x_val, y_val, verbose=0)
print(f"모델3 정확도(Validation): {val_acc3:.4f}")
# Out:
# 모델3 정확도(Validation): 0.9873

# %% [markdown]
# ### (4) 모델4 :  학습률, epoch 등 조정

# %%
# 모델 설계
def build_model4():
    model = Sequential([
        Input(shape=(input_dim,)),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.4),

        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.3),

        Dense(64, activation='relu'),
        Dropout(0.3),

        Dense(32, activation='relu'),
        Dropout(0.2),

        Dense(num_classes, activation='softmax')
    ])
    return model

model4 = build_model4()
model4.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_13 (Dense)                │ (None, 128)            │        71,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 6)              │           198 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 87,398 (341.40 KB)
#  Trainable params: 87,014 (339.90 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
# 컴파일 및 학습
model4.compile(
    optimizer=Adam(learning_rate=0.0003),  # 더 낮은 학습률로 안정적 학습
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history4 = model4.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
# Epoch 37/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9724 - loss: 0.0825 - val_accuracy: 0.9881 - val_loss: 0.0433
# Epoch 38/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9659 - loss: 0.0932 - val_accuracy: 0.9839 - val_loss: 0.0403
# Epoch 39/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9669 - loss: 0.0905 - val_accuracy: 0.9847 - val_loss: 0.0485
# Epoch 40/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9699 - loss: 0.0846 - val_accuracy: 0.9703 - val_loss: 0.0728
# Epoch 41/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9666 - loss: 0.0975 - val_accuracy: 0.9830 - val_loss: 0.0428
# Epoch 42/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9738 - loss: 0.0713 - val_accuracy: 0.9847 - val_loss: 0.0488
# Epoch 43/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9749 - loss: 0.0777 - val_accuracy: 0.9830 - val_loss: 0.0432
# Epoch 44/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9715 - loss: 0.0799 - val_accuracy: 0.9626 - val_loss: 0.1005
# Epoch 45/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9761 - loss: 0.0680 - val_accuracy: 0.9822 - val_loss: 0.0507
# Epoch 46/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9761 - loss: 0.0768 - val_accuracy: 0.9796 - val_loss: 0.0667
# Epoch 47/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9709 - loss: 0.0895 - val_accuracy: 0.9779 - val_loss: 0.0650
# Epoch 48/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9718 - loss: 0.0861 - val_accuracy: 0.9856 - val_loss: 0.0446
# Epoch 49/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9709 - loss: 0.0772 - val_accuracy: 0.9813 - val_loss: 0.0556
# Epoch 50/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9785 - loss: 0.0698 - val_accuracy: 0.9822 - val_loss: 0.0445

# %%
# 학습곡선
dl_history_plot(history4.history)

# %%
# 예측 및 평가
val_loss4, val_acc4 = model4.evaluate(x_val, y_val, verbose=0)
print(f"모델4 정확도(Validation): {val_acc4:.4f}")
# Out:
# 모델4 정확도(Validation): 0.9822

# %% [markdown]
# ## 4.성능비교

# %% [markdown]
# * 세부 요구사항
#     - test 데이터에 대한 전처리
#     - 각 모델에 대해서 test 데이터로 성능 측정

# %%
#전체 데이터 불러오기(test)
test_df = pd.read_csv(path + '/data01_test.csv')
# subject 삭제
test_df = test_df.drop(columns=['subject'])
# x, y 분할
X_test = test_df.drop(columns=['Activity'])
y_test = test_df['Activity']
# x : 스케일링 적용
X_test_scaled = scaler.transform(X_test)
# y : 정수인코딩 적용
y_test_encoded = le.transform(y_test)

# %%
# test 데이터에 대한 성능 측정
def evaluate_model_on_test(model, name="Model"):
    loss, acc = model.evaluate(X_test_scaled, y_test_encoded, verbose=0)
    print(f"{name} Test Accuracy: {acc:.4f}")
    return acc

acc_test1 = evaluate_model_on_test(model1, "모델1")
acc_test2 = evaluate_model_on_test(model2, "모델2")
acc_test3 = evaluate_model_on_test(model3, "모델3")
acc_test4 = evaluate_model_on_test(model4, "모델4")

results_df = pd.DataFrame({
    '모델': ['모델1', '모델2', '모델3', '모델4'],
    'Test Accuracy': [acc_test1, acc_test2, acc_test3, acc_test4]
})

print("\n최종 성능 비교:")
display(results_df.sort_values(by='Test Accuracy', ascending=False))
# Out:
# 모델1 Test Accuracy: 0.9742
# 모델2 Test Accuracy: 0.9769
# 모델3 Test Accuracy: 0.9796
# 모델4 Test Accuracy: 0.9782
#
# 최종 성능 비교:
#     모델  Test Accuracy
# 2  모델3       0.979606
# 3  모델4       0.978246
# 1  모델2       0.976886
# 0  모델1       0.974167

# %% [markdown]
# #### 고생하셨습니다! 이제 단계적 모델링을 해봅시다.
